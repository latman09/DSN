# %% [markdown]
# <a href="https://colab.research.google.com/github/latman09/DSN/blob/main/DSN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # * ***IMPORT NECESSARY LIBRARY***

# %%
import numpy as np      # For arrays and numerical operations
import pandas as pd     # For loading and manipulating datasets
import matplotlib.pyplot as plt  # For data visualization
import seaborn as sns    # For data visualization
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report  # For performance metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt # Import matplotlib for plotting
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # ***LOAD DATA SET ***

# %%
test=pd.read_csv('/Test Dataset.csv')
train=pd.read_csv('/Train Dataset .csv')
sample=pd.read_csv('/Sample Submission.csv')
test.head()
train.head()
sample.head()
# Out:
#       Id
# 0  16501
# 1  10444
# 2  14288
# 3  10409
# 4  17330

# %% [markdown]
# ## **CHECK INFOMATION ON THE NEW DATA SET**

# %%
test.info()
train.info()
sample.info()
test.describe()
train.describe()
sample.describe()
print(test.shape)
print(train.shape)
print(sample.shape)
sample.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2697 entries, 0 to 2696
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        2697 non-null   int64
#  1   age       2697 non-null   int64
#  2   sex       2697 non-null   int64
#  3   cp        2697 non-null   int64
#  4   trestbps  2697 non-null   int64
#  5   chol      2697 non-null   int64
#  6   fbs       2697 non-null   int64
#  7   restecg   2697 non-null   int64
#  8   thalach   2697 non-null   int64
#  9   exang     2697 non-null   int64
#  10  oldpeak   2697 non-null   float64
#  11  slope     2697 non-null   int64
#  12  ca        2697 non-null   int64
#  13  thal      2697 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 295.1 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7303 entries, 0 to 7302
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
# ...

# %% [markdown]
# # **CLEANINNG AND MANIPULATION OF THE DATA**

# %%
train['target'].describe()
train['target'].value_counts()

train.head()
train_f=train.drop(['Age','Sex','cp','trestbps','chol','fbs','restecg','thalach','exang','slope','ca','thal'],axis=1)
train_f.head()
test_f=test.drop(['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','slope','ca','thal','oldpeak'],axis=1)
test_f.head()
# Out:
#       id
# 0  16501
# 1  10444
# 2  14288
# 3  10409
# 4  17330

# %% [markdown]
# # **MACHINE LEARNING MODDEL**

# %%
X=train_f.drop('target',axis=1)
y=train_f['target']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # **VISUALIZATION OF DECISSION TREE**

# %%
plt.figure(figsize=(10, 8))
tree.plot_tree(clf, filled=True, rounded=True) # Call plot_tree from the tree module
plt.show() # Display the plot

# %% [markdown]
# # **BUILDING OF DECISSION TREE**

# %%
clf=DecisionTreeClassifier()
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # **EVALUATE THE MODEL**

# %%
y_pred=clf.predict(X_test)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.17      0.19      0.18       444
#            1       0.81      0.79      0.80      1966
#
#     accuracy                           0.68      2410
#    macro avg       0.49      0.49      0.49      2410
# weighted avg       0.70      0.68      0.69      2410
#
# [[  85  359]
#  [ 405 1561]]
# 0.6829875518672199
